# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('income_per_person_gdppercapita_ppp_inflation_adjusted.csv')

# %%
df.describe()
# Out:
#               1800         1801         1802         1803         1804  \
# count   193.000000   193.000000   193.000000   193.000000   193.000000
# mean    947.782383   948.269430   951.217617   950.911917   952.772021
# std     508.348372   506.753967   516.692581   511.552526   518.974690
# min     350.000000   350.000000   350.000000   350.000000   350.000000
# 25%     608.000000   608.000000   608.000000   609.000000   609.000000
# 50%     847.000000   847.000000   847.000000   847.000000   848.000000
# 75%    1100.000000  1100.000000  1110.000000  1110.000000  1110.000000
# max    4230.000000  4160.000000  4390.000000  4300.000000  4500.000000
#
#               1805         1806         1807         1808         1809  ...  \
# count   193.000000   193.000000   193.000000   193.000000   193.000000  ...
# mean    953.202073   954.305699   953.979275   950.911917   952.202073  ...
# std     513.492023   514.667191   508.132446   490.318368   492.600302  ...
# ...

# %%
df.shape
# Out:
# (193, 242)

# %%
# Create the scatter plot
df.plot(kind='scatter', x='1800', y='2015')

# Specify axis labels
plt.xlabel('Income by Country in 1800')
plt.ylabel('Income by Country in 2015')

# Specify axis limits
plt.xlim(100 )
# plt.ylim(20, 55)

# Display the plot
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ce1bdb0cf410> in <module>
# ----> 1 df.std(max)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10974                                       skipna=skipna, ddof=ddof)
#   10975         return self._reduce(f, name, axis=axis, numeric_only=numeric_only,
# > 10976                             skipna=skipna, ddof=ddof)
#   10977
#   10978     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7389         else:
#    7390             # TODO: Make other agg func handle axis=None properly
# -> 7391             axis = self._get_axis_number(axis)
#    7392             labels = self._get_agg_axis(axis)
# ...
